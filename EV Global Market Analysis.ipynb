# %% [markdown]
# # **EV Market Analysis (Cars)**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter

# %%
Global_Historical_Cars_Data = pd.read_csv("/content/drive/MyDrive/EV analysis/EV Data/Global/IEA-EV-dataEV salesHistoricalCars.csv")
Global_Historical_Cars_Data['value'] = Global_Historical_Cars_Data['value'].astype(float)
pd.set_option('display.float_format', '{:.0f}'.format)
Global_Historical_Cars_Data
# Out:
#       region    category       parameter  mode powertrain  year      unit  \
# 0     Africa  Historical        EV sales  Cars        BEV  2013  Vehicles
# 1     Africa  Historical        EV stock  Cars        BEV  2013  Vehicles
# 2     Africa  Historical  EV sales share  Cars         EV  2013   percent
# 3     Africa  Historical  EV stock share  Cars         EV  2013   percent
# 4     Africa  Historical  EV stock share  Cars         EV  2014   percent
# ...      ...         ...             ...   ...        ...   ...       ...
# 4965   World  Historical        EV stock  Cars       FCEV  2024  Vehicles
# 4966   World  Historical        EV stock  Cars        BEV  2024  Vehicles
# 4967   World  Historical        EV sales  Cars       FCEV  2024  Vehicles
# 4968   World  Historical        EV sales  Cars        BEV  2024  Vehicles
# 4969   World  Historical  Battery demand  Cars         EV  2024       GWh
#
#         value
# 0          34
# 1          34
# 2           0
# 3           0
# 4           0
# ...       ...
# 4965    70000
# 4966 39000000
# 4967     5300
# 4968 11000000
# 4969      840
#
# [4970 rows x 8 columns]

# %%
Global_Historical_Cars_Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4970 entries, 0 to 4969
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   region      4970 non-null   object
#  1   category    4970 non-null   object
#  2   parameter   4970 non-null   object
#  3   mode        4970 non-null   object
#  4   powertrain  4970 non-null   object
#  5   year        4970 non-null   int64
#  6   unit        4970 non-null   object
#  7   value       4970 non-null   float64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 310.8+ KB

# %%
Global_Historical_Cars_Data['parameter'].value_counts()
# Out:
# parameter
# EV sales                         1727
# EV stock                         1543
# EV sales share                    780
# EV stock share                    650
# Oil displacement Mbd               90
# Oil displacement, million lge      90
# Battery demand                     90
# Name: count, dtype: int64

# %% [markdown]
# EV sales - 	           Number of EVs sold
# EV stock	-           Total EVs in use
# EV sales share	-   % of vehicles sold that are EVs
# EV stock share	 -  % of total vehicles that are EVs

# %%
Global_Historical_Cars_Data['powertrain'].value_counts()
# Out:
# powertrain
# EV      1700
# BEV     1425
# PHEV    1248
# FCEV     597
# Name: count, dtype: int64

# %% [markdown]
# 1. EV (Electric Vehicle)
# 2. BEV (Battery Electric Vehicle)
# 3. PHEV (Plug-in Hybrid Electric Vehicle)
# 4. FCEV (Fuel Cell Electric Vehicle)

# %%
Global_Historical_Cars_Data['region'].value_counts().head(10)
# Out:
# region
# World                164
# Europe               163
# USA                  155
# Rest of the world    150
# China                143
# India                123
# EU27                 117
# Belgium              115
# Asia Pacific         114
# Japan                112
# Name: count, dtype: int64

# %%
EV_sales = Global_Historical_Cars_Data[Global_Historical_Cars_Data['parameter'] == "EV sales"]
EV_sales = EV_sales.sort_values(by='year').reset_index(drop=True)
EV_sales = EV_sales.rename(columns={'value' : 'Total sales'})
EV_sales
# Out:
#                  region    category parameter  mode powertrain  year  \
# 0                 Japan  Historical  EV sales  Cars       FCEV  2010
# 1     Rest of the world  Historical  EV sales  Cars        BEV  2010
# 2                 World  Historical  EV sales  Cars        BEV  2010
# 3                 Korea  Historical  EV sales  Cars        BEV  2010
# 4                 World  Historical  EV sales  Cars       FCEV  2010
# ...                 ...         ...       ...   ...        ...   ...
# 1722          Australia  Historical  EV sales  Cars        BEV  2024
# 1723              World  Historical  EV sales  Cars       PHEV  2024
# 1724             Poland  Historical  EV sales  Cars        BEV  2024
# 1725             Poland  Historical  EV sales  Cars       FCEV  2024
# 1726             Poland  Historical  EV sales  Cars       PHEV  2024
#
#           unit  Total sales
# 0     Vehicles            2
# 1     Vehicles          450
# 2     Vehicles         7000
# 3     Vehicles           61
# 4     Vehicles           13
# ...        ...          ...
# 1722  Vehicles        91000
# 1723  Vehicles      6500000
# 1724  Vehicles        17000
# 1725  Vehicles            7
# 1726  Vehicles        15000
#
# [1727 rows x 8 columns]

# %%
EV_stock = Global_Historical_Cars_Data[Global_Historical_Cars_Data['parameter'] == "EV stock"]
EV_stock = EV_stock.sort_values(by='year').reset_index(drop=True)
EV_stock = EV_stock.rename(columns={'value' : 'Total stock'})
EV_stock
# Out:
#               region    category parameter  mode powertrain  year      unit  \
# 0              Korea  Historical  EV stock  Cars        BEV  2010  Vehicles
# 1     United Kingdom  Historical  EV stock  Cars       PHEV  2010  Vehicles
# 2        New Zealand  Historical  EV stock  Cars        BEV  2010  Vehicles
# 3     United Kingdom  Historical  EV stock  Cars        BEV  2010  Vehicles
# 4             Sweden  Historical  EV stock  Cars        BEV  2010  Vehicles
# ...              ...         ...       ...   ...        ...   ...       ...
# 1538    Asia Pacific  Historical  EV stock  Cars       PHEV  2024  Vehicles
# 1539    Asia Pacific  Historical  EV stock  Cars        BEV  2024  Vehicles
# 1540          Africa  Historical  EV stock  Cars       PHEV  2024  Vehicles
# 1541          Africa  Historical  EV stock  Cars        BEV  2024  Vehicles
# 1542          Africa  Historical  EV stock  Cars       FCEV  2024  Vehicles
#
#       Total stock
# 0              61
# 1              21
# 2              14
# 3            1500
# 4               4
# ...           ...
# 1538     11000000
# 1539     24000000
# 1540         4200
# 1541        15000
# 1542            3
#
# [1543 rows x 8 columns]

# %%
powertrain_wise_sales = EV_sales.pivot_table(
    index='year',
    columns='powertrain',
    values='Total sales',
    aggfunc='sum'
).reset_index()
powertrain_wise_sales = powertrain_wise_sales.rename(columns={'BEV' : 'BEV sales', 'PHEV' : 'PHEV sales', 'FCEV' : 'FCEV sales'})
powertrain_wise_sales
# Out:
# powertrain  year  BEV sales  FCEV sales  PHEV sales
# 0           2010      22038          39        1443
# 1           2011     127234         NaN       27153
# 2           2012     186229           3      187622
# 3           2013     357473          88      296160
# 4           2014     622364         290      417231
# 5           2015    1029942        2330      619968
# 6           2016    1453545        7500     1009119
# 7           2017    2352668       10878     1413190
# 8           2018    4264769       13640     2040297
# 9           2019    4801457       23039     1869511
# 10          2020    6538967       23596     3420692
# 11          2021   14831090       48759     6577060
# 12          2022   22952627       46448     9459259
# 13          2023   29922360       27815    13407431
# 14          2024   33993800       16956    20240121

# %%
powertrain_wise_stock = EV_stock.pivot_table(
    index='year',
    columns='powertrain',
    values='Total stock',
    aggfunc='sum'
).reset_index()
powertrain_wise_stock = powertrain_wise_stock.rename(columns={'BEV' : 'BEV stock', 'PHEV' : 'PHEV stock', 'FCEV' : 'FCEV stock'})
powertrain_wise_stock
# Out:
# powertrain  year  BEV stock  FCEV stock  PHEV stock
# 0           2010      64219          74        1246
# 1           2011     186349          74       28602
# 2           2012     374411          74      216989
# 3           2013     725024          80      513178
# 4           2014    1304707         276      940191
# 5           2015    2305934        2646     1672700
# 6           2016    3724953        9568     2603272
# 7           2017    6014413       21085     3921756
# 8           2018    9926984       34051     5971390
# 9           2019   14857074       58385     7646257
# 10          2020   21306643       80222    11057116
# 11          2021   35433598      128209    17608781
# 12          2022   57128900      174970    26499809
# 13          2023   88029160      202445    39880003
# 14          2024  122021300      216040    60398860

# %%
Year_wise_sales = EV_sales.groupby('year')['Total sales'].sum().reset_index()
Year_wise_stock = EV_stock.groupby('year')['Total stock'].sum().reset_index()
Year_wise_sales_stock = pd.merge(Year_wise_sales, Year_wise_stock, on='year')
Year_wise_sales_stock
# Out:
#     year  Total sales  Total stock
# 0   2010        23520        65539
# 1   2011       154387       215025
# 2   2012       373854       591474
# 3   2013       653721      1238282
# 4   2014      1039885      2245174
# 5   2015      1652240      3981280
# 6   2016      2470164      6337793
# 7   2017      3776736      9957254
# 8   2018      6318706     15932425
# 9   2019      6694007     22561716
# 10  2020      9983255     32443981
# 11  2021     21456909     53170588
# 12  2022     32458334     83803679
# 13  2023     43357606    128111608
# 14  2024     54250877    182636200

# %%
Year_and_powertrain_wise_sales = pd.merge(powertrain_wise_sales, Year_wise_sales, on='year')
Year_and_powertrain_wise_sales
# Out:
#     year  BEV sales  FCEV sales  PHEV sales  Total sales
# 0   2010      22038          39        1443        23520
# 1   2011     127234         NaN       27153       154387
# 2   2012     186229           3      187622       373854
# 3   2013     357473          88      296160       653721
# 4   2014     622364         290      417231      1039885
# 5   2015    1029942        2330      619968      1652240
# 6   2016    1453545        7500     1009119      2470164
# 7   2017    2352668       10878     1413190      3776736
# 8   2018    4264769       13640     2040297      6318706
# 9   2019    4801457       23039     1869511      6694007
# 10  2020    6538967       23596     3420692      9983255
# 11  2021   14831090       48759     6577060     21456909
# 12  2022   22952627       46448     9459259     32458334
# 13  2023   29922360       27815    13407431     43357606
# 14  2024   33993800       16956    20240121     54250877

# %%
Year_and_powertrain_wise_stock = pd.merge(powertrain_wise_stock, Year_wise_stock, on='year')
Year_and_powertrain_wise_stock
# Out:
#     year  BEV stock  FCEV stock  PHEV stock  Total stock
# 0   2010      64219          74        1246        65539
# 1   2011     186349          74       28602       215025
# 2   2012     374411          74      216989       591474
# 3   2013     725024          80      513178      1238282
# 4   2014    1304707         276      940191      2245174
# 5   2015    2305934        2646     1672700      3981280
# 6   2016    3724953        9568     2603272      6337793
# 7   2017    6014413       21085     3921756      9957254
# 8   2018    9926984       34051     5971390     15932425
# 9   2019   14857074       58385     7646257     22561716
# 10  2020   21306643       80222    11057116     32443981
# 11  2021   35433598      128209    17608781     53170588
# 12  2022   57128900      174970    26499809     83803679
# 13  2023   88029160      202445    39880003    128111608
# 14  2024  122021300      216040    60398860    182636200

# %%
Total_sales_stock = pd.merge(Year_and_powertrain_wise_sales, Year_and_powertrain_wise_stock, on='year').fillna(0)
Total_sales_stock.replace()
# Out:
# /tmp/ipython-input-14-1773323987.py:2: FutureWarning: DataFrame.replace without 'value' and with non-dict-like 'to_replace' is deprecated and will raise in a future version. Explicitly specify the new values instead.
#   Total_sales_stock.replace()
#     year  BEV sales  FCEV sales  PHEV sales  Total sales  BEV stock  \
# 0   2010      22038          39        1443        23520      64219
# 1   2011     127234           0       27153       154387     186349
# 2   2012     186229           3      187622       373854     374411
# 3   2013     357473          88      296160       653721     725024
# 4   2014     622364         290      417231      1039885    1304707
# 5   2015    1029942        2330      619968      1652240    2305934
# 6   2016    1453545        7500     1009119      2470164    3724953
# 7   2017    2352668       10878     1413190      3776736    6014413
# 8   2018    4264769       13640     2040297      6318706    9926984
# 9   2019    4801457       23039     1869511      6694007   14857074
# 10  2020    6538967       23596     3420692      9983255   21306643
# 11  2021   14831090       48759     6577060     21456909   35433598
# 12  2022   22952627       46448     9459259     32458334   57128900
# 13  2023   29922360       27815    13407431     43357606   88029160
# 14  2024   33993800       16956    20240121     54250877  122021300
#
#     FCEV stock  PHEV stock  Total stock
# 0           74        1246        65539
# 1           74       28602       215025
# 2           74      216989       591474
# 3           80      513178      1238282
# 4          276      940191      2245174
# 5         2646     1672700      3981280
# 6         9568     2603272      6337793
# 7        21085     3921756      9957254
# 8        34051     5971390     15932425
# 9        58385     7646257     22561716
# 10       80222    11057116     32443981
# 11      128209    17608781     53170588
# 12      174970    26499809     83803679
# 13      202445    39880003    128111608
# 14      216040    60398860    182636200

# %%
import plotly.express as px

melted_sales = powertrain_wise_sales.melt(
    id_vars='year',
    value_vars=['BEV sales', 'PHEV sales', 'FCEV sales'],
    var_name='powertrain',
    value_name='sales'
)

color_map = {
    'BEV sales': 'blue',
    'PHEV sales': 'skyblue',
    'FCEV sales': 'black'
}

fig = px.bar(
    melted_sales,
    x='year',
    y='sales',
    color='powertrain',
    color_discrete_map=color_map,
    barmode='group',
    title='Total Sales of Different Powertrains Over Time (Global - Cars)',
    labels={'year': 'Year', 'sales': 'Total Sales'},
    height=600
)

fig.update_layout(
    xaxis=dict(
        tickmode='array',
        tickvals=list(range(2010, 2025))
    ),
    yaxis_tickformat=',',
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="685dd464-2a5a-43fa-8c3e-611e47c5f30e" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("685dd464-2a5a-43fa-8c3e-611e47c5f30e")) {                    Plotly.newPlot(                        "685dd464-2a5a-43fa-8c3e-611e47c5f30e",                        [{"alignmentgroup":"True","hovertemplate":"powertrain=BEV sales\u003cbr\u003eYear=%{x}\u003cbr\u003eTotal Sales=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"BEV sales","marker":{"color":"blue","pattern":{"shape":""}},"name":"BEV sales","offsetgroup":"BEV sales","orientation":"v","showlegend":true,"textposition":"auto","x":[2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022,2023,2024],"xaxis":"x","y":[22038.0,127234.0,186229.0,357473.0,622364.0,1029942.0,1453545.0,2352668.0,4264769.0,4801457.0,6538967.0,14831090.0,22952627.0,29922360.0,33993800.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"powertrain=PHEV sales\u003cbr\u003eYear=%{x}\u003cbr\u003eTotal Sales=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"PHEV sales","marker":{"color":"skyblue","pattern":{"shape":""}},"name":"PHEV sales","offsetgroup":"PHEV sales","orientation":"v","showlegend":true,"textposition":"auto","x":[2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022,2023,2024],"xaxis":"x","y":[1443.0,27153.0,187622.0,296160.0,417231.0,619968.0,1009119.0,1413190.0,2040297.0,1869511.0,3420692.0,6577060.0,9459259.0,13407431.0,20240121.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"powertrain=FCEV sales\u003cbr\u003eYear=%{x}\u003cbr\u003eTotal Sales=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"FCEV sales","marker":{"color":"black","pattern":{"shape":""}},"name":"FCEV sales","offsetgroup":"FCEV sales","orientation":"v","showlegend":true,"textposition":"auto","x":[2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022,2023,2024],"xaxis":"x","y":[39.0,null,3.0,88.0,290.2000000476837,2330.0,7500.0,10878.0,13640.0,23039.0,23596.0,48759.0,46448.0,27815.0,16956.0],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarp ...

# %%
melted_stock = powertrain_wise_stock.melt(
    id_vars='year',
    value_vars=['BEV stock', 'PHEV stock', 'FCEV stock'],
    var_name='powertrain',
    value_name='stock'
)

color_map = {
    'BEV stock': 'blue',
    'PHEV stock': 'skyblue',
    'FCEV stock': 'black'
}

fig = px.bar(
    melted_stock,
    x='year',
    y='stock',
    color='powertrain',
    color_discrete_map=color_map,
    barmode='group',
    title='Total available Stock of Different Powertrains Over Time (Global - Cars)',
    labels={'year': 'Year', 'stock': 'Total Stock'},
    height=600
)

fig.update_layout(
    xaxis=dict(
        tickmode='array',
        tickvals=list(range(2010, 2025))
    ),
    yaxis_tickformat=',',
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="587e461a-9c3c-42ab-94db-f9fe23c908d4" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("587e461a-9c3c-42ab-94db-f9fe23c908d4")) {                    Plotly.newPlot(                        "587e461a-9c3c-42ab-94db-f9fe23c908d4",                        [{"alignmentgroup":"True","hovertemplate":"powertrain=BEV stock\u003cbr\u003eYear=%{x}\u003cbr\u003eTotal Stock=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"BEV stock","marker":{"color":"blue","pattern":{"shape":""}},"name":"BEV stock","offsetgroup":"BEV stock","orientation":"v","showlegend":true,"textposition":"auto","x":[2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022,2023,2024],"xaxis":"x","y":[64219.0,186349.0,374411.0,725024.0,1304707.0,2305934.0,3724953.0,6014413.0,9926984.0,14857074.0,21306643.0,35433598.0,57128900.0,88029160.0,122021300.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"powertrain=PHEV stock\u003cbr\u003eYear=%{x}\u003cbr\u003eTotal Stock=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"PHEV stock","marker":{"color":"skyblue","pattern":{"shape":""}},"name":"PHEV stock","offsetgroup":"PHEV stock","orientation":"v","showlegend":true,"textposition":"auto","x":[2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022,2023,2024],"xaxis":"x","y":[1246.0,28602.0,216989.0,513178.0,940191.0,1672700.0,2603272.0,3921756.0,5971390.0,7646257.0,11057116.0,17608781.0,26499809.0,39880003.0,60398860.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"powertrain=FCEV stock\u003cbr\u003eYear=%{x}\u003cbr\u003eTotal Stock=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"FCEV stock","marker":{"color":"black","pattern":{"shape":""}},"name":"FCEV stock","offsetgroup":"FCEV stock","orientation":"v","showlegend":true,"textposition":"auto","x":[2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022,2023,2024],"xaxis":"x","y":[74.0,74.0,74.0,80.0,276.2000000476837,2646.0,9568.0,21085.0,34051.0,58384.90000009537,80221.90000009537,128208.89999961853,174970.0,202445.0,216040.0],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888 ...

# %%
melted = Year_wise_sales_stock.melt(
    id_vars='year',
    value_vars=['Total sales', 'Total stock'],
    var_name='sales-stock',
    value_name='sales_stock'
)

color_map = {
    'Total sales': 'skyblue',
    'Total stock': 'blue'
}

fig = px.bar(
    melted,
    x='year',
    y='sales_stock',
    color='sales-stock',
    color_discrete_map=color_map,
    barmode='group',
    title='Total Sales VS Total Stock Over Time (Global - Cars)',
    labels={'year': 'Year', 'sales_stock': 'Total Sales VS Total Stock'},
    height=600
)

fig.update_layout(
    xaxis=dict(
        tickmode='array',
        tickvals=list(range(2010, 2025))
    ),
    yaxis_tickformat=',',
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="41a2495b-c146-4919-848c-9c2518e15e19" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("41a2495b-c146-4919-848c-9c2518e15e19")) {                    Plotly.newPlot(                        "41a2495b-c146-4919-848c-9c2518e15e19",                        [{"alignmentgroup":"True","hovertemplate":"sales-stock=Total sales\u003cbr\u003eYear=%{x}\u003cbr\u003eTotal Sales VS Total Stock=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Total sales","marker":{"color":"skyblue","pattern":{"shape":""}},"name":"Total sales","offsetgroup":"Total sales","orientation":"v","showlegend":true,"textposition":"auto","x":[2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022,2023,2024],"xaxis":"x","y":[23520.0,154387.0,373854.0,653721.0,1039885.2000000477,1652240.0,2470164.0,3776736.0,6318706.0,6694007.0,9983255.0,21456909.0,32458334.0,43357606.0,54250877.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"sales-stock=Total stock\u003cbr\u003eYear=%{x}\u003cbr\u003eTotal Sales VS Total Stock=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Total stock","marker":{"color":"blue","pattern":{"shape":""}},"name":"Total stock","offsetgroup":"Total stock","orientation":"v","showlegend":true,"textposition":"auto","x":[2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022,2023,2024],"xaxis":"x","y":[65539.0,215025.0,591474.0,1238282.0,2245174.2000000477,3981280.0,6337793.0,9957254.0,15932425.0,22561715.900000095,32443980.900000095,53170587.89999962,83803679.0,128111608.0,182636200.0],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"o ...

# %% [markdown]
# # **EV Market Analysis (Two, Three Wheelers)**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter

# %%
Global_Historical_Two_Three_Wheeler_Data = pd.read_csv("/content/drive/MyDrive/EV analysis/EV Data/Global/IEA-EV-dataEV salesHistorical2 and 3 wheelers.csv")
Global_Historical_Two_Three_Wheeler_Data['value'] = Global_Historical_Two_Three_Wheeler_Data['value'].astype(float)
pd.set_option('display.float_format', '{:.0f}'.format)
Global_Historical_Two_Three_Wheeler_Data
# Out:
#       region    category       parameter              mode powertrain  year  \
# 0     Africa  Historical        EV sales  2 and 3 wheelers        BEV  2015
# 1     Africa  Historical  EV sales share  2 and 3 wheelers         EV  2015
# 2     Africa  Historical  EV sales share  2 and 3 wheelers         EV  2016
# 3     Africa  Historical        EV sales  2 and 3 wheelers        BEV  2016
# 4     Africa  Historical        EV sales  2 and 3 wheelers        BEV  2017
# ...      ...         ...             ...               ...        ...   ...
# 2632   World  Historical  EV stock share  2 and 3 wheelers         EV  2024
# 2633   World  Historical        EV sales  2 and 3 wheelers        BEV  2024
# 2634   World  Historical        EV stock  2 and 3 wheelers       FCEV  2024
# 2635   World  Historical        EV stock  2 and 3 wheelers        BEV  2024
# 2636   World  Historical  Battery demand  2 and 3 wheelers         EV  2024
#
#           unit    value
# 0     Vehicles       80
# 1      percent        0
# 2      percent        0
# 3     Vehicles       45
# 4     Vehicles       60
# ...        ...      ...
# 2632   percent        9
# 2633  Vehicles 10000000
# 2634  Vehicles        6
# 2635  Vehicles 79000000
# 2636       GWh       32
#
# [2637 rows x 8 columns]

# %%
Global_Historical_Two_Three_Wheeler_Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2637 entries, 0 to 2636
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   region      2637 non-null   object
#  1   category    2637 non-null   object
#  2   parameter   2637 non-null   object
#  3   mode        2637 non-null   object
#  4   powertrain  2637 non-null   object
#  5   year        2637 non-null   int64
#  6   unit        2637 non-null   object
#  7   value       2637 non-null   float64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 164.9+ KB

# %%
Global_Historical_Two_Three_Wheeler_Data['parameter'].value_counts()
# Out:
# parameter
# EV stock                         647
# EV sales                         601
# EV sales share                   567
# EV stock share                   564
# Oil displacement, million lge     86
# Battery demand                    86
# Oil displacement Mbd              86
# Name: count, dtype: int64

# %%
Global_Historical_Two_Three_Wheeler_Data['powertrain'].value_counts()
# Out:
# powertrain
# EV      1389
# BEV     1131
# FCEV      62
# PHEV      55
# Name: count, dtype: int64

# %%
Global_Historical_Two_Three_Wheeler_Data['region'].value_counts().head(10)
# Out:
# region
# World                131
# Europe               128
# India                105
# Rest of the world     97
# USA                   91
# China                 91
# EU27                  75
# Asia Pacific          72
# New Zealand           72
# United Kingdom        66
# Name: count, dtype: int64

# %%
EV_sales1 = Global_Historical_Two_Three_Wheeler_Data[Global_Historical_Two_Three_Wheeler_Data['parameter'] == "EV sales"]
EV_sales1 = EV_sales1.sort_values(by='year').reset_index(drop=True)
EV_sales1 = EV_sales1.rename(columns={'value' : 'Total sales'})
EV_sales1
# Out:
#              region    category parameter              mode powertrain  year  \
# 0    United Kingdom  Historical  EV sales  2 and 3 wheelers        BEV  2010
# 1      Asia Pacific  Historical  EV sales  2 and 3 wheelers        BEV  2010
# 2       New Zealand  Historical  EV sales  2 and 3 wheelers        BEV  2010
# 3            Israel  Historical  EV sales  2 and 3 wheelers        BEV  2010
# 4             India  Historical  EV sales  2 and 3 wheelers        BEV  2010
# ..              ...         ...       ...               ...        ...   ...
# 596         Belgium  Historical  EV sales  2 and 3 wheelers        BEV  2024
# 597         Austria  Historical  EV sales  2 and 3 wheelers        BEV  2024
# 598        Viet Nam  Historical  EV sales  2 and 3 wheelers        BEV  2024
# 599       Australia  Historical  EV sales  2 and 3 wheelers        BEV  2024
# 600    Asia Pacific  Historical  EV sales  2 and 3 wheelers        BEV  2024
#
#          unit  Total sales
# 0    Vehicles          550
# 1    Vehicles        41000
# 2    Vehicles           14
# 3    Vehicles           11
# 4    Vehicles        40000
# ..        ...          ...
# 596  Vehicles         3400
# 597  Vehicles         3500
# 598  Vehicles       250000
# 599  Vehicles         6800
# 600  Vehicles      9700000
#
# [601 rows x 8 columns]

# %%
EV_stock1 = Global_Historical_Two_Three_Wheeler_Data[Global_Historical_Two_Three_Wheeler_Data['parameter'] == "EV stock"]
EV_stock1 = EV_stock1.sort_values(by='year').reset_index(drop=True)
EV_stock1 = EV_stock1.rename(columns={'value' : 'Total stock'})
EV_stock1
# Out:
#              region    category parameter              mode powertrain  year  \
# 0             World  Historical  EV stock  2 and 3 wheelers        BEV  2010
# 1      Asia Pacific  Historical  EV stock  2 and 3 wheelers        BEV  2010
# 2           Belgium  Historical  EV stock  2 and 3 wheelers        BEV  2010
# 3          Thailand  Historical  EV stock  2 and 3 wheelers        BEV  2010
# 4    United Kingdom  Historical  EV stock  2 and 3 wheelers        BEV  2010
# ..              ...         ...       ...               ...        ...   ...
# 642    Asia Pacific  Historical  EV stock  2 and 3 wheelers        BEV  2024
# 643    Asia Pacific  Historical  EV stock  2 and 3 wheelers       FCEV  2024
# 644    Asia Pacific  Historical  EV stock  2 and 3 wheelers       PHEV  2024
# 645           World  Historical  EV stock  2 and 3 wheelers        BEV  2024
# 646          Africa  Historical  EV stock  2 and 3 wheelers        BEV  2024
#
#          unit  Total stock
# 0    Vehicles        50000
# 1    Vehicles        48000
# 2    Vehicles          110
# 3    Vehicles         7700
# 4    Vehicles         1700
# ..        ...          ...
# 642  Vehicles     77000000
# 643  Vehicles            2
# 644  Vehicles            1
# 645  Vehicles     79000000
# 646  Vehicles        25000
#
# [647 rows x 8 columns]

# %%
powertrain_wise_sales1 = EV_sales1.pivot_table(
    index='year',
    columns='powertrain',
    values='Total sales',
    aggfunc='sum'
).reset_index()
powertrain_wise_sales1 = powertrain_wise_sales1.rename(columns={'BEV' : 'BEV sales', 'PHEV' : 'PHEV sales', 'FCEV' : 'FCEV sales'})
powertrain_wise_sales1
# Out:
# powertrain  year  BEV sales  FCEV sales  PHEV sales
# 0           2010     123726         NaN         NaN
# 1           2011      92240         NaN         NaN
# 2           2012    6001808         NaN         NaN
# 3           2013    6937040         NaN         NaN
# 4           2014    8297800         NaN          51
# 5           2015    8369154         NaN          54
# 6           2016    9380637         NaN          33
# 7           2017   10907635         NaN         NaN
# 8           2018   15533479         NaN         NaN
# 9           2019   20023792           8         NaN
# 10          2020   26556332           4           3
# 11          2021   34244427          10           8
# 12          2022   29552327         NaN          12
# 13          2023   30205091         NaN         NaN
# 14          2024   30001767         NaN         NaN

# %%
powertrain_wise_stock1 = EV_stock1.pivot_table(
    index='year',
    columns='powertrain',
    values='Total stock',
    aggfunc='sum'
).reset_index()
powertrain_wise_stock1 = powertrain_wise_stock1.rename(columns={'BEV' : 'BEV stock', 'PHEV' : 'PHEV stock', 'FCEV' : 'FCEV stock'})
powertrain_wise_stock1
# Out:
# powertrain  year  BEV stock  FCEV stock  PHEV stock
# 0           2010     149600         NaN         NaN
# 1           2011     304723         NaN         NaN
# 2           2012    6043391         NaN         NaN
# 3           2013   12409967         NaN         NaN
# 4           2014   20062493         NaN         NaN
# 5           2015   28329399          16          81
# 6           2016   38285450          28         NaN
# 7           2017   50311013          60         NaN
# 8           2018   66761409          56         NaN
# 9           2019   90177343          48           3
# 10          2020  114178710          56           3
# 11          2021  144545540          54          11
# 12          2022  160171970          54          23
# 13          2023  208610040          50         161
# 14          2024  237565040          22         161

# %%
Year_wise_sales1 = EV_sales1.groupby('year')['Total sales'].sum().reset_index()
Year_wise_stock1 = EV_stock1.groupby('year')['Total stock'].sum().reset_index()
Year_wise_sales_stock1 = pd.merge(Year_wise_sales1, Year_wise_stock1, on='year')
Year_wise_sales_stock1
# Out:
#     year  Total sales  Total stock
# 0   2010       123726       149600
# 1   2011        92240       304723
# 2   2012      6001808      6043391
# 3   2013      6937040     12409967
# 4   2014      8297851     20062493
# 5   2015      8369208     28329496
# 6   2016      9380670     38285478
# 7   2017     10907635     50311073
# 8   2018     15533479     66761465
# 9   2019     20023800     90177394
# 10  2020     26556339    114178769
# 11  2021     34244445    144545605
# 12  2022     29552339    160172047
# 13  2023     30205091    208610251
# 14  2024     30001767    237565223

# %%
Year_and_powertrain_wise_sales1 = pd.merge(powertrain_wise_sales1, Year_wise_sales1, on='year')
Year_and_powertrain_wise_sales1
# Out:
#     year  BEV sales  FCEV sales  PHEV sales  Total sales
# 0   2010     123726         NaN         NaN       123726
# 1   2011      92240         NaN         NaN        92240
# 2   2012    6001808         NaN         NaN      6001808
# 3   2013    6937040         NaN         NaN      6937040
# 4   2014    8297800         NaN          51      8297851
# 5   2015    8369154         NaN          54      8369208
# 6   2016    9380637         NaN          33      9380670
# 7   2017   10907635         NaN         NaN     10907635
# 8   2018   15533479         NaN         NaN     15533479
# 9   2019   20023792           8         NaN     20023800
# 10  2020   26556332           4           3     26556339
# 11  2021   34244427          10           8     34244445
# 12  2022   29552327         NaN          12     29552339
# 13  2023   30205091         NaN         NaN     30205091
# 14  2024   30001767         NaN         NaN     30001767

# %%
Year_and_powertrain_wise_stock1 = pd.merge(powertrain_wise_stock1, Year_wise_stock1, on='year')
Year_and_powertrain_wise_stock1
# Out:
#     year  BEV stock  FCEV stock  PHEV stock  Total stock
# 0   2010     149600         NaN         NaN       149600
# 1   2011     304723         NaN         NaN       304723
# 2   2012    6043391         NaN         NaN      6043391
# 3   2013   12409967         NaN         NaN     12409967
# 4   2014   20062493         NaN         NaN     20062493
# 5   2015   28329399          16          81     28329496
# 6   2016   38285450          28         NaN     38285478
# 7   2017   50311013          60         NaN     50311073
# 8   2018   66761409          56         NaN     66761465
# 9   2019   90177343          48           3     90177394
# 10  2020  114178710          56           3    114178769
# 11  2021  144545540          54          11    144545605
# 12  2022  160171970          54          23    160172047
# 13  2023  208610040          50         161    208610251
# 14  2024  237565040          22         161    237565223

# %%
Total_sales_stock1 = pd.merge(Year_and_powertrain_wise_sales1, Year_and_powertrain_wise_stock1, on='year').fillna(0)
Total_sales_stock1.replace()
# Out:
# /tmp/ipython-input-31-3185668222.py:2: FutureWarning:
#
# DataFrame.replace without 'value' and with non-dict-like 'to_replace' is deprecated and will raise in a future version. Explicitly specify the new values instead.
#     year  BEV sales  FCEV sales  PHEV sales  Total sales  BEV stock  \
# 0   2010     123726           0           0       123726     149600
# 1   2011      92240           0           0        92240     304723
# 2   2012    6001808           0           0      6001808    6043391
# 3   2013    6937040           0           0      6937040   12409967
# 4   2014    8297800           0          51      8297851   20062493
# 5   2015    8369154           0          54      8369208   28329399
# 6   2016    9380637           0          33      9380670   38285450
# 7   2017   10907635           0           0     10907635   50311013
# 8   2018   15533479           0           0     15533479   66761409
# 9   2019   20023792           8           0     20023800   90177343
# 10  2020   26556332           4           3     26556339  114178710
# 11  2021   34244427          10           8     34244445  144545540
# 12  2022   29552327           0          12     29552339  160171970
# 13  2023   30205091           0           0     30205091  208610040
# 14  2024   30001767           0           0     30001767  237565040
#
#     FCEV stock  PHEV stock  Total stock
# 0            0           0       149600
# 1            0           0       304723
# 2            0           0      6043391
# 3            0           0     12409967
# 4            0           0     20062493
# 5           16          81     28329496
# 6           28           0     38285478
# 7           60           0     50311073
# 8           56           0     66761465
# 9           48           3     90177394
# 10          56           3    114178769
# 11          54          11    144545605
# 12          54          23    160172047
# 13          50         161    208610251
# 14          22         161    237565223

# %%
import plotly.express as px

melted_sales = powertrain_wise_sales1.melt(
    id_vars='year',
    value_vars=['BEV sales'],
    var_name='powertrain1',
    value_name='sales1'
)

color_map = {
    'BEV sales': 'blue'
}

fig = px.bar(
    melted_sales,
    x='year',
    y='sales1',
    color='powertrain1',
    color_discrete_map=color_map,
    barmode='group',
    title='Total Sales of Different Powertrains Over Time (Global - Two, Three Wheelers)',
    labels={'year': 'Year', 'sales': 'Total Sales'},
    height=600,
)

fig.update_layout(
    xaxis=dict(
        tickmode='array',
        tickvals=list(range(2010, 2025))
    ),
    yaxis_tickformat=',',
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="ea6e47f5-78df-460f-8c13-a9912b370700" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ea6e47f5-78df-460f-8c13-a9912b370700")) {                    Plotly.newPlot(                        "ea6e47f5-78df-460f-8c13-a9912b370700",                        [{"alignmentgroup":"True","hovertemplate":"powertrain1=BEV sales\u003cbr\u003eYear=%{x}\u003cbr\u003esales1=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"BEV sales","marker":{"color":"blue","pattern":{"shape":""}},"name":"BEV sales","offsetgroup":"BEV sales","orientation":"v","showlegend":true,"textposition":"auto","x":[2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022,2023,2024],"xaxis":"x","y":[123726.0,92240.0,6001808.0,6937040.0,8297800.0,8369154.0,9380637.0,10907635.0,15533479.0,20023792.0,26556332.0,34244427.0,29552327.0,30205091.0,30001767.0],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f" ...

# %%
melted_stock = powertrain_wise_stock1.melt(
    id_vars='year',
    value_vars=['BEV stock'],
    var_name='powertrain1',
    value_name='stock1'
)

color_map = {
    'BEV stock': 'blue'
}

fig = px.bar(
    melted_stock,
    x='year',
    y='stock1',
    color='powertrain1',
    color_discrete_map=color_map,
    barmode='group',
    title='Total available Stock of Different Powertrains Over Time (Global - Two, Three Wheelers)',
    labels={'year': 'Year', 'stock': 'Total Stock'},
    height=600
)

fig.update_layout(
    xaxis=dict(
        tickmode='array',
        tickvals=list(range(2010, 2025))
    ),
    yaxis_tickformat=',',
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="3290662e-2028-4918-8a7a-21039e19b699" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3290662e-2028-4918-8a7a-21039e19b699")) {                    Plotly.newPlot(                        "3290662e-2028-4918-8a7a-21039e19b699",                        [{"alignmentgroup":"True","hovertemplate":"powertrain1=BEV stock\u003cbr\u003eYear=%{x}\u003cbr\u003estock1=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"BEV stock","marker":{"color":"blue","pattern":{"shape":""}},"name":"BEV stock","offsetgroup":"BEV stock","orientation":"v","showlegend":true,"textposition":"auto","x":[2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022,2023,2024],"xaxis":"x","y":[149600.0,304723.0,6043391.0,12409967.0,20062493.0,28329399.0,38285450.0,50311013.0,66761409.0,90177343.0,114178710.0,144545540.0,160171970.0,208610040.0,237565040.0],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color" ...

# %%
melted = Year_wise_sales_stock1.melt(
    id_vars='year',
    value_vars=['Total sales', 'Total stock'],
    var_name='sales-stock1',
    value_name='sales_stock1'
)

color_map = {
    'Total sales': 'skyblue',
    'Total stock': 'blue'
}

fig = px.bar(
    melted,
    x='year',
    y='sales_stock1',
    color='sales-stock1',
    color_discrete_map=color_map,
    barmode='group',
    title='Total Sales VS Total Stock Over Time (Global - Two, Three Wheelers)',
    labels={'year': 'Year', 'sales_stock': 'Total Sales VS Total Stock'},
    height=600
)

fig.update_layout(
    xaxis=dict(
        tickmode='array',
        tickvals=list(range(2010, 2025))
    ),
    yaxis_tickformat=',',
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="f159696a-28d7-409f-9d84-6203b9db351d" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f159696a-28d7-409f-9d84-6203b9db351d")) {                    Plotly.newPlot(                        "f159696a-28d7-409f-9d84-6203b9db351d",                        [{"alignmentgroup":"True","hovertemplate":"sales-stock1=Total sales\u003cbr\u003eYear=%{x}\u003cbr\u003esales_stock1=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Total sales","marker":{"color":"skyblue","pattern":{"shape":""}},"name":"Total sales","offsetgroup":"Total sales","orientation":"v","showlegend":true,"textposition":"auto","x":[2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022,2023,2024],"xaxis":"x","y":[123726.0,92240.0,6001808.0,6937040.0,8297851.0,8369208.0,9380670.0,10907635.0,15533479.0,20023800.0,26556339.0,34244445.0,29552339.0,30205091.0,30001767.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"sales-stock1=Total stock\u003cbr\u003eYear=%{x}\u003cbr\u003esales_stock1=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Total stock","marker":{"color":"blue","pattern":{"shape":""}},"name":"Total stock","offsetgroup":"Total stock","orientation":"v","showlegend":true,"textposition":"auto","x":[2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022,2023,2024],"xaxis":"x","y":[149600.0,304723.0,6043391.0,12409967.0,20062493.0,28329496.0,38285478.0,50311073.0,66761465.0,90177394.0,114178769.0,144545605.0,160172047.0,208610251.0,237565223.0],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0 ...

# %% [markdown]
# # **Cars VS Two, Three Wheelers**

# %%
Cars_Two_Three_Wheelers_Data = pd.merge(Total_sales_stock[['year', 'BEV sales', 'Total sales', 'BEV stock', 'Total stock']], Total_sales_stock1[['year', 'BEV sales', 'Total sales', 'BEV stock', 'Total stock']], on='year')
Cars_Two_Three_Wheelers_Data
# Out:
#     year  BEV sales_x  Total sales_x  BEV stock_x  Total stock_x  BEV sales_y  \
# 0   2010        22038          23520        64219          65539       123726
# 1   2011       127234         154387       186349         215025        92240
# 2   2012       186229         373854       374411         591474      6001808
# 3   2013       357473         653721       725024        1238282      6937040
# 4   2014       622364        1039885      1304707        2245174      8297800
# 5   2015      1029942        1652240      2305934        3981280      8369154
# 6   2016      1453545        2470164      3724953        6337793      9380637
# 7   2017      2352668        3776736      6014413        9957254     10907635
# 8   2018      4264769        6318706      9926984       15932425     15533479
# 9   2019      4801457        6694007     14857074       22561716     20023792
# 10  2020      6538967        9983255     21306643       32443981     26556332
# 11  2021     14831090       21456909     35433598       53170588     34244427
# 12  2022     22952627       32458334     57128900       83803679     29552327
# 13  2023     29922360       43357606     88029160      128111608     30205091
# 14  2024     33993800       54250877    122021300      182636200     30001767
#
#     Total sales_y  BEV stock_y  Total stock_y
# 0          123726       149600         149600
# 1           92240       304723         304723
# 2         6001808      6043391        6043391
# 3         6937040     12409967       12409967
# 4         8297851     20062493       20062493
# 5         8369208     28329399       28329496
# 6         9380670     38285450       38285478
# 7        10907635     50311013       50311073
# 8        15533479     66761409       66761465
# 9        20023800     90177343       90177394
# 10       26556339    114178710      114178769
# 11       34244445    144545540      144545605
# 12       29552339    160171970      160172047
# 13       30205091    208610040      208610251
# 14       30001767    237565040      237565223

# %% [markdown]
# We only consider Two Wheeler. Because Two Wheeler's sales is greater than Three Wheeler's sales.
# And we consider only BEV type Two Wheeler for our analysis.

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots

fig = make_subplots(
    rows=2, cols=2,
    subplot_titles=[
        "BEV Sales: Cars vs Two-Wheelers",
        "Total Sales: Cars vs Two-Wheelers",
        "BEV Stock: Cars vs Two-Wheelers",
        "Total Stock: Cars vs Two-Wheelers"
    ]
)

years = Cars_Two_Three_Wheelers_Data['year'].astype(str)

fig.add_trace(go.Bar(x=years, y=Cars_Two_Three_Wheelers_Data['BEV sales_x'], name="BEV Car Sales", marker_color="#03045e"), row=1, col=1)
fig.add_trace(go.Bar(x=years, y=Cars_Two_Three_Wheelers_Data['BEV sales_y'], name="BEV 2W Sales", marker_color="#00b4d8"), row=1, col=1)

fig.add_trace(go.Bar(x=years, y=Cars_Two_Three_Wheelers_Data['Total sales_x'], name="Total Car Sales", marker_color="#023e8a"), row=1, col=2)
fig.add_trace(go.Bar(x=years, y=Cars_Two_Three_Wheelers_Data['Total sales_y'], name="Total 2W Sales", marker_color="#48cae4"), row=1, col=2)

fig.add_trace(go.Bar(x=years, y=Cars_Two_Three_Wheelers_Data['BEV stock_x'], name="BEV Car Stock", marker_color="#240046"), row=2, col=1)
fig.add_trace(go.Bar(x=years, y=Cars_Two_Three_Wheelers_Data['BEV stock_y'], name="BEV 2W Stock", marker_color="#7b2cbf"), row=2, col=1)

fig.add_trace(go.Bar(x=years, y=Cars_Two_Three_Wheelers_Data['Total stock_x'], name="Total Car Stock", marker_color="#3c096c"), row=2, col=2)
fig.add_trace(go.Bar(x=years, y=Cars_Two_Three_Wheelers_Data['Total stock_y'], name="Total 2W Stock", marker_color="#9d4edd"), row=2, col=2)

fig.update_layout(
    height=950,
    width=1500,
    title_text="Car vs Two-Wheeler (Global): Sales and Stock Comparison (BEV & Total)",
    barmode='group',
    legend=dict(x=1.05),
    showlegend=True
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="a1bd1872-8221-4760-ab85-bb63dd546344" class="plotly-graph-div" style="height:950px; width:1500px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a1bd1872-8221-4760-ab85-bb63dd546344")) {                    Plotly.newPlot(                        "a1bd1872-8221-4760-ab85-bb63dd546344",                        [{"marker":{"color":"#03045e"},"name":"BEV Car Sales","x":["2010","2011","2012","2013","2014","2015","2016","2017","2018","2019","2020","2021","2022","2023","2024"],"y":[22038.0,127234.0,186229.0,357473.0,622364.0,1029942.0,1453545.0,2352668.0,4264769.0,4801457.0,6538967.0,14831090.0,22952627.0,29922360.0,33993800.0],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#00b4d8"},"name":"BEV 2W Sales","x":["2010","2011","2012","2013","2014","2015","2016","2017","2018","2019","2020","2021","2022","2023","2024"],"y":[123726.0,92240.0,6001808.0,6937040.0,8297800.0,8369154.0,9380637.0,10907635.0,15533479.0,20023792.0,26556332.0,34244427.0,29552327.0,30205091.0,30001767.0],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#023e8a"},"name":"Total Car Sales","x":["2010","2011","2012","2013","2014","2015","2016","2017","2018","2019","2020","2021","2022","2023","2024"],"y":[23520.0,154387.0,373854.0,653721.0,1039885.2000000477,1652240.0,2470164.0,3776736.0,6318706.0,6694007.0,9983255.0,21456909.0,32458334.0,43357606.0,54250877.0],"type":"bar","xaxis":"x2","yaxis":"y2"},{"marker":{"color":"#48cae4"},"name":"Total 2W Sales","x":["2010","2011","2012","2013","2014","2015","2016","2017","2018","2019","2020","2021","2022","2023","2024"],"y":[123726.0,92240.0,6001808.0,6937040.0,8297851.0,8369208.0,9380670.0,10907635.0,15533479.0,20023800.0,26556339.0,34244445.0,29552339.0,30205091.0,30001767.0],"type":"bar","xaxis":"x2","yaxis":"y2"},{"marker":{"color":"#240046"},"name":"BEV Car Stock","x":["2010","2011","2012","2013","2014","2015","2016","2017","2018","2019","2020","2021","2022","2023","2024"],"y":[64219.0,186349.0,374411.0,725024.0,1304707.0,2305934.0,3724953.0,6014413.0,9926984.0,14857074.0,21306643.0,35433598.0,57128900.0,88029160.0,122021300.0],"type":"bar","xaxis":"x3","yaxis":"y3"},{"marker":{"color":"#7b2cbf"},"name":"BEV 2W Stock","x":["2010","2011","2012","2013","2014","2015","2016","2017","2018","2019","2020","2021","2022","2023","2024"],"y":[149600.0,304723.0,6043391.0,12409967.0,20062493.0,28329399.0,38285450.0,50311013.0,66761409.0,90177343.0,114178710.0,144545540.0,160171970.0,208610040.0,237565040.0],"type":"bar","xaxis":"x3","yaxis":"y3"},{"marker":{"color":"#3c096c"},"name":"Total Car Stock","x":["2010","2011","2012","2013","2014","2015","2016","2017","2018","2019","2020","2021","2022","2023","2024"],"y":[65539.0,215025.0,591474.0,1238282.0,2245174.2000000477,3981280.0,6337793.0,9957254.0,15932425.0,22561715.900000095,32443980.900000095,53170587.89999962,83803679.0,128111608.0,182636200.0],"type":"bar","xaxis":"x4","yaxis":"y4"},{"marker":{"color":"#9d4edd"},"name":"Total 2W Stock","x":["2010","2011","2012","2013","2014","2015","2016","2017","2018","2019","2020","2021","2022","2023","2024"],"y":[149600.0,304723.0,6043391.0,12409967.0,20062493.0,28329496.0,38285478.0,50311073.0,66761465.0,90177394.0,114178769.0,144545605.0,160172047.0,208610251.0,237565223.0],"type":"bar","xaxis":"x4","yaxis":"y4"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth" ...

# %% [markdown]
# # **Conclusion:**
#
# **The visual analysis of Battery Electric Vehicle (BEV) and total vehicle data for cars vs two-wheelers from 2010 to 2024 reveals several important trends:**
#
# **1. BEV Sales Comparison:**
# 1. Two-wheelers consistently lead BEV sales over the years, significantly outperforming cars.
# 2. However, BEV car sales have shown sharp growth after 2018, indicating a rising adoption trend, especially from 2020 onwards.
# 3. The sales gap between cars and two-wheelers is narrowing, highlighting growing consumer interest in electric cars.
#
# **2. Total Sales Comparison:**
# 1. Total two-wheeler sales are consistently higher than total car sales, reflecting affordability and mass-market appeal.
# 2. Car sales exhibit a steady growth trend, especially in the recent years, suggesting improving purchasing power and market expansion.
#
# **3. BEV Stock Comparison:**
# 1. Similar to sales, BEV stock for two-wheelers remains higher throughout the timeline.
# 2. BEV car stock, though lower in earlier years, shows a strong upward curve from 2020 onward, aligning with rising sales and infrastructure development.
#
# **4. Total Stock Comparison:**
# 1. Total stock of two-wheelers is again greater, but car stock is rapidly growing, particularly after 2020.
# 2. The narrowing gap suggests increased investments in car production and supply chain resilience in the automotive sector.
